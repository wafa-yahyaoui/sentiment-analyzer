# %%
import urllib3
import facebook
import requests
import csv
import tweepy
from tweepy import OAuthHandler
import twitter

# %%
token = "EAABZBwxwxyXMBAPuUvf6wqDVdJhXcQ5tWZCv42S3UFfZAao935GEou3bFKOPbY2YjOok3r3N6QseA1A1h5OmKJnvizQGWe1DqyBGH494NoGhwxjDD7bRrPTEocSLw2uN1RpPk7TZB5QkQtxJwtbdvQn6Nzw6ZAWDZCD5Li2XCd8QZDZD"
graph = facebook.GraphAPI(access_token=token, version = 2.7)
pagesdata = requests.get("https://graph.facebook.com/me/accounts?access_token="+token)
page_id = "298166859034"

# %%
posts_on_page = requests.get("https://graph.facebook.com/"+page_id+"/posts?access_token="+token)
posts_data = (posts_on_page.json())
comments=[]
for x in posts_data['data']:
    post_id = x['id']
    reactions_on_post = requests.get("https://graph.facebook.com/"+post_id+"/comments?access_token="+token)
    reactions_data = reactions_on_post.json() 
    for element in reactions_data['data']:
        comments.append(element['message'])
#print(comments)

# %%
posts_on_page = requests.get("https://graph.facebook.com/"+page_id+"/posts?access_token="+token)
posts_data = (posts_on_page.json())
comments=[]
date=[]
liste=[]
sousliste=[]
for x in posts_data['data']:
    post_id = x['id']
    reactions_on_post = requests.get("https://graph.facebook.com/"+post_id+"/comments?access_token="+token)
    reactions_data = reactions_on_post.json() 
    for element in reactions_data['data']:
        sousliste.append(element['message'])
        sousliste.append("positive")
        sousliste.append(element['created_time'])
        sousliste.append(post_id)
        liste.extend([sousliste])
        sousliste=[]
#print(liste)

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import names
 
def word_feats(words):
    return dict([(word, True) for word in words])
 
positive_vocab = [ 'رابحين', 'farna','mahlekom' 'fantastic', 'Mabrouk', 'good', 'nice', 'great', ':)' ,'5eir','😘',' bon','😍','satisfied',' Keep it','❤','💕','merci','yo','برافو ','امشيختنا' ,'امربحتنا ','امدللتنا','مبروووك']
negative_vocab = [ 'قديمة', 'تكذبو ','الخساره', 'hate','سرقتوه' ':(','kedb ' ,'sirka','Mahouch','عيب','😥','😢','التفاهاات','😭','💔 ','استهتار','jboura','inutile','problème','السرقة','tay7a']

 
positive_features = [(word_feats(pos), 'pos') for pos in positive_vocab]
negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]
#neutral_features = []

 
train_set = negative_features + positive_features # + neutral_features
 
classifier = NaiveBayesClassifier.train(train_set) 

posts_on_page = requests.get("https://graph.facebook.com/"+page_id+"/posts?access_token="+token)
posts_data = (posts_on_page.json())
comments=[]
liste =[]
for x in posts_data['data']:
    post_id = x['id']
    reactions_on_post = requests.get("https://graph.facebook.com/"+post_id+"/comments?access_token="+token)
    reactions_data = reactions_on_post.json() 
    for element in reactions_data['data']:
        comments.append(element['message'])
#print(liste)
s_liste_pos=[]
liste_pos=[]
s_liste_neg=[]
liste_neg=[]
for i in comments:
    neg = 0
    pos = 0
    #print (i)
    i = i.lower()
    words = i.split(' ')
    for word in words:
        classResult = classifier.classify( word_feats(word))
        if classResult == 'neg':
            neg = neg + 1
        if classResult == 'pos':
            pos = pos + 1
        p = float(pos)/len(words)
        n = float(neg)/len(words)
 
    #print('Positive: ' + str(p))
    #print('Negative: ' + str(n))

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import names
 
def word_feats(words):
    return dict([(word, True) for word in words])
 
positive_vocab = [ 'رابحين', 'farna','mahlekom' 'fantastic', 'Mabrouk', 'good', 'nice', 'great', ':)' ,'5eir','😘',' bon','😍','satisfied',' Keep it','❤','💕','merci','yo','برافو ','امشيختنا' ,'امربحتنا ','امدللتنا','مبروووك']
negative_vocab = [ 'قديمة', 'تكذبو ','الخساره', 'hate', ':(','kedb ' ,'sirka','Mahouch','عيب','😥','😢','التفاهاات','😭','💔 ','استهتار','jboura','inutile','problème','السرقة','tay7a']

 
positive_features = [(word_feats(pos), 'pos') for pos in positive_vocab]
negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]
#neutral_features = []

 
train_set = negative_features + positive_features # + neutral_features
 
classifier = NaiveBayesClassifier.train(train_set) 

posts_on_page = requests.get("https://graph.facebook.com/"+page_id+"/posts?access_token="+token)
posts_data = (posts_on_page.json())
comments=[]
liste =[]
for x in posts_data['data']:
    post_id = x['id']
    reactions_on_post = requests.get("https://graph.facebook.com/"+post_id+"/comments?access_token="+token)
    reactions_data = reactions_on_post.json() 
    for element in reactions_data['data']:
        comments.append(element['message'])
#print(liste)
s_liste_pos=[]
liste_pos=[]
s_liste_neg=[]
liste_neg=[]
for i in comments:
    neg = 0
    pos = 0
    #print (i)
    i = i.lower()
    words = i.split(' ')
    for word in words:
        s_liste_pos=[]
        s_liste_neg=[]
        classResult = classifier.classify( word_feats(word))
        if classResult == 'neg':
            neg = neg + 1
        if classResult == 'pos':
            pos = pos + 1
        p = float(pos)/len(words)
        n = float(neg)/len(words) 
    #print(p)
    #print(n)
    if(p>n):
        s_liste_pos.append(i)
        s_liste_pos.append("positive")
        liste_pos.extend([s_liste_pos])
    if(p<n):
        s_liste_neg.append(i)
        s_liste_neg.append("negative")
        liste_neg.extend([s_liste_neg]) 
#print(liste_pos)
#print(liste_neg)

# %%
with open("data/sentiment_category_pos.csv", "w", encoding='utf-8') as f_write:
    writer = csv.writer(f_write)
    for row in liste_pos:
        writer.writerow(row)

# %%
with open("data/sentiment_category_neg.csv", "w", encoding='UTF-8') as f_write:
    writer = csv.writer(f_write)
    for row in liste_neg:
        writer.writerow(row)

# %%
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import names
 
def word_feats(words):
    return dict([(word, True) for word in words])
 
positive_vocab = [ 'رابحين', 'farna','mahlekom' 'fantastic', 'Mabrouk', 'good', 'nice', 'great', ':)' ,'5eir','😘',' bon','😍','satisfied',' Keep it','❤','💕','merci','yo','برافو ','امشيختنا' ,'امربحتنا ','امدللتنا','مبروووك']
negative_vocab = [ 'قديمة', 'تكذبو ','الخساره', 'hate', ':(','kedb ' ,'sirka','Mahouch','عيب','😥','😢','التفاهاات','😭','💔 ','استهتار','jboura','inutile','problème','السرقة','tay7a']

 
positive_features = [(word_feats(pos), 'pos') for pos in positive_vocab]
negative_features = [(word_feats(neg), 'neg') for neg in negative_vocab]
#neutral_features = []

 
train_set = negative_features + positive_features # + neutral_features
 
classifier = NaiveBayesClassifier.train(train_set) 

posts_on_page = requests.get("https://graph.facebook.com/"+page_id+"/posts?access_token="+token)
posts_data = (posts_on_page.json())
comments=[]
liste =[]
for x in posts_data['data']:
    post_id = x['id']
    reactions_on_post = requests.get("https://graph.facebook.com/"+post_id+"/comments?access_token="+token)
    reactions_data = reactions_on_post.json() 
    for element in reactions_data['data']:
        comments.append(element['message'])
#print(liste)
s_liste=[]
liste1 = []
for i in comments:
    neg = 0
    pos = 0
    #print (i)
    i = i.lower()
    words = i.split(' ')
    for word in words:
        s_liste=[]
        classResult = classifier.classify( word_feats(word))
        if classResult == 'neg':
            neg = neg + 1
        if classResult == 'pos':
            pos = pos + 1
        p = float(pos)/len(words)
        n = float(neg)/len(words) 
    s_liste.append(i)
    if(p>n or p==n):
        s_liste.append("positive")
        liste1.extend([s_liste])
    if(p<n):
        s_liste.append("negative")
        liste1.extend([s_liste]) 
print(liste1)
# Out:
# [['عسلامة أورونج رقدت مخلي ال puce متاعي أورونج قمت نلقاها تبدلت أوريدو بلاهي كيفاش نبدلها تليكوم', 'negative'], ['اورونج نحب نقلكم عيشكم خاتر انتوما الوحدين\n\nتتفكروني\nتعيدو عليا قبل عيلتي\nو مبعد تبعثولي ميساج تقولولي راهو فلوسك وفاو\nتعرف الي انا مبارح صبيت دينار ياخي سرقتوه تعرفووووو...😠😠\nمصح الرقعة 😑\nكان جيت انجم نقتل واحد راني مشيت طول انلوج الي يبعثلي مساج يقلي فيه راهو فلوسك وفاو😈\nو شكرا .....\nمن دون تصفيق 😂😂', 'positive'], ['brabi orange pk l connexion ma t7ebech temchili kan fcbk 7ata le messenger ma najemtech na3mlelha téléchargement en plus le play store ma 7abech chniya ilmochkla brabi', 'positive'], ['slm orange elyoum 3adet fourfi 900 ta3 7 jour tan7tli 1800 maya a3lech na7touhem dima tasrli hadi', 'positive'], ['عسلامة أورونج كل منعمل internet ونحط ماتش نتفرج فيه نلقى بينالتي لترجي زعما م ريزو ضعيف وإلpuce عادمة  . !!', 'positive'], ['الطبيب يداوي والفرج على ربي de quelle couleur est le carré 😂😂😂😂😂😂😂🍅🍅🍅', 'positive'], ['نسالكم 70 ميغاا الله لا تربحكم انتم باش تربحوو الشعب يا متحيلين ان شاء الله 70 ميغاا تطلعلكم 70 مليار خسارة', 'positive'], ['bara taw kol we7ed bech t8ochou luminosité mte3ou 😂😂 ena n9oul "c"', 'positive'], ["bon orange pk la connexion t
positive'], ['larou riahi joyeux anniversaire o kol aam oenty hay b 1000 khir matagek had ntagik ena 😂😂😂💪', 'positive'], ['sawsen bellil o5ti l3ziza nchallah kol 3am wanti hiy b alf 5ir w rabi 5lik liya ya a7la o5et fi denya', 'positive'], ['rihab ben mehrez ena o o5ty zynna ❤️😍 joyeux anniversaire habybty 😘💘💋', 'positive'], ['hedhly zh khaoula haboubtyyyy.joyeux anniversaire bel msaba9   💟💟💟 nheeebeek 💓😘', 'positive'], ['انا و ر ...

# %%
posts_on_page = requests.get("https://graph.facebook.com/"+page_id+"/posts?access_token="+token)
posts_data = (posts_on_page.json())
comments=[]
date=[]
liste2=[]
sousliste=[]
for x in posts_data['data']:
    post_id = x['id']
    reactions_on_post = requests.get("https://graph.facebook.com/"+post_id+"/comments?access_token="+token)
    reactions_data = reactions_on_post.json() 
    for element in reactions_data['data']:
        #sousliste.append(element['message'])
        #sousliste.append("positive")
        sousliste.append(element['created_time'])
        sousliste.append("https://www.facebook.com/"+post_id)
        liste2.extend([sousliste])
        sousliste=[]
print(liste2)
# Out:
# [['2018-01-02T19:16:17+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:43:48+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T20:37:47+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:00:49+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T22:04:49+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:09:48+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:11:40+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T20:10:01+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T20:47:32+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T21:43:12+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T21:23:16+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T20:50:09+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T21:34:23+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T20:19:17+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:04:03+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:03:13+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:03:03+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:06:14+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:01:56+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:00:54+0000', 'https://www.facebook.com/298166859034_10155976149264035'], ['2018-01-02T19:05:28+0000', 'https://www.facebook.com/298166859034_10155976
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)
cricTweet = tweepy.Cursor(api.search, q='@OrangeTN').items(500)

# %%
tweets=[]
for tweet in cricTweet:
    print(tweet.text)
    tweets.append(tweet.text)
    
with open('comments.csv', 'a') as f:
    writer = csv.writer(f)
    for val in tweets:
        writer.writerow([val])
# Out:
# RT @karim2k: La générosité de @OrangeTN un voyage au coupé du monde 2018 au fameux CM de @ooredootn Wajih par son prénom  😄 💟💝💘 https://t.c…
# La générosité de @OrangeTN un voyage au coupé du monde 2018 au fameux CM de @ooredootn Wajih par son prénom  😄 💟💝💘 https://t.co/FzrynCCjAN
# Riles, i like this one too,it was a show!   Thanks to our team and partners @OrangeTN https://t.co/9z3OC3UExq
# @OrangeTN Pepsi man
# @OrangeTN_Plus @OrangeTN Bravo !!!
# RT @millet_thierry: Première de Riles en Tunisie : de beaux débuts pour une belle histoire @OrangeTN https://t.co/9ToPqsDDSE
# @OrangeTN Top 👍
# il y a un problème d'ADSL @OrangeTN ?
# Première de Riles en Tunisie : de beaux débuts pour une belle histoire @OrangeTN https://t.co/9ToPqsDDSE
# RT @OrangeTN_Plus: #Solidarity always wins ! Bravo aux bénévoles d'@OrangeTN et de l'association "un enfant, des sourires" pour la réussite…
# @OrangeTN sa7a noum
# RT @OrangeTN_Plus: #Solidarity always wins ! Bravo aux bénévoles d'@OrangeTN et de l'association "un enfant, des sourires" pour la réussite…
# @OrangeTN الاعب اسمو wxfdwyzugzqhyifc بن بسغمىفثضسه يلعب في المانيا
# #Solidarity always wins ! Bravo aux bénévoles d'@OrangeTN et de l'association "un enfant, des sourires" pour la réu… https://t.co/vnxFkXPafm
# @OrangeTN Need for speed
# @OrangeTN Rayman 👍
# RT @elacheche: .@Topnet_FSI &amp; @OrangeTN can you please share a detailed #Technical #PressRelease or #report about the @Huawei #HG532e incid…
# Top brands on Twitter in Tunisia: @OrangeTN @Leaders_Tunisie @CLtounes @waleg @lesannoncesTN https://t.co/KCceFL7vU7
# @OrangeTN I remember I loved the legend of the dragoon !
# @OrangeTN The Avengers !
# @OrangeTN GTA
# @slimKhan @elacheche @OrangeTN @Topnet_FSI @Huawei @WelidNaffati @MedAliSouissi You made my day xD
# @slimKhan @OrangeTN @Topnet_FSI @Huawei @WelidNaffati @MedAliSouissi That's lovely!! :D ping @WelidNaffati  @MedAliSouissi
# @elacheche @OrangeTN @Topnet_FSI @Huawei @WelidNaffati @MedAliSouissi xD https://t.co/9hTk1ktnvL
# @slimKhan @OrangeTN @Topnet_FSI @Huawei @WelidNaffati @MedAliSouissi Seriously?!! :o
# @OrangeTN @elacheche @Topnet_FSI @Huawei @WelidNaffati @MedAliSouissi W Kamel es2elhom pk ba3D el maj fel orange el… https://t.co/G51E8v2IR5
# @OrangeTN 20/3
# RT @OrangeTN: Fan d'#HarryPotter et du monde de #Poudlard ✨? Réjouissez-vous car un nouveau jeu de rôle sur #mobile #HogwartsMystery sera l…
